# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
import numpy as np

# %%
df=pd.read_csv('Stores.csv')
df.head()
# Out:
#    Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 0          1        1659             1961                   530        66490
# 1          2        1461             1752                   210        39820
# 2          3        1340             1609                   720        54010
# 3          4        1451             1748                   620        53730
# 4          5        1770             2111                   450        46620

# %% [markdown]
# ## Exploring the Data

# %%
df.shape
# Out:
# (896, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 896 entries, 0 to 895
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Store ID              896 non-null    int64
#  1   Store_Area            896 non-null    int64
#  2   Items_Available       896 non-null    int64
#  3   Daily_Customer_Count  896 non-null    int64
#  4   Store_Sales           896 non-null    int64
# dtypes: int64(5)
# memory usage: 35.1 KB

# %% [markdown]
# > According to this, there are no null values present in our dataset

# %%
df.describe()
# Out:
#         Store ID    Store_Area  Items_Available  Daily_Customer_Count  \
# count  896.000000   896.000000       896.000000            896.000000
# mean   448.500000  1485.409598      1782.035714            786.350446
# std    258.797218   250.237011       299.872053            265.389281
# min      1.000000   775.000000       932.000000             10.000000
# 25%    224.750000  1316.750000      1575.500000            600.000000
# 50%    448.500000  1477.000000      1773.500000            780.000000
# 75%    672.250000  1653.500000      1982.750000            970.000000
# max    896.000000  2229.000000      2667.000000           1560.000000
#
#          Store_Sales
# count     896.000000
# mean    59351.305804
# std     17190.741895
# min     14920.000000
# 25%     46530.000000
# 50%     58605.000000
# 75%     71872.500000
# max    116320.000000

# %%
df.tail()
# Out:
#      Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 891        892        1582             1910                  1080        66390
# 892        893        1387             1663                   850        82080
# 893        894        1200             1436                  1060        76440
# 894        895        1299             1560                   770        96610
# 895        896        1174             1429                  1110        54340

# %%
df.describe().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_87655_row0_col0, #T_87655_row7_col0, #T_87655_row7_col1, #T_87655_row7_col2, #T_87655_row7_col3, #T_87655_row7_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_87655_row0_col1 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_87655_row0_col2, #T_87655_row4_col0 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_87655_row0_col3 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_87655_row0_col4, #T_87655_row2_col1, #T_87655_row2_col2, #T_87655_row3_col0, #T_87655_row3_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_87655_row1_col0, #T_87655_row1_col3, #T_87655_row5_col0 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_87655_row1_col1, #T_87655_row5_col2 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_87655_row1_col2 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_87655_row1_col4 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_87655_row2_col0 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_87655_row2_col3 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_87655_row2_col4 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_87655_row3_col1 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_87655_row3_col2 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_87655_row3_col4 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_87655_row4_col1, #T_87655_row4_col2 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_87655_row4_col3 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_87655_row4_col4 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_87655_row5_col1, #T_87655_row6_col3 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_87655_row5_col3, #T_87655_row5_col4 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_87655_row6_col0 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_87655_row6_col1, #T_87655_row6_col2 {
#   background-color: #2c7cba;
#   color: #f1f1f1;
# }
# #T_87655_row6_col4 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_87655">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_87655_level0_col0" class="col_heading level0 col0" >Store ID </th>
#       <th id="T_87655_level0_col1" class="col_heading level0 col1" >Store_Area</th>
#       <th id="T_87655_level0_col2" class="col_heading level0 col2" >Items_Available</th>
#       <th id="T_87655_level0_col3" class="col_heading level0 col3" >Daily_Customer_Count</th>
#       <th id="T_87655_level0_col4" class="col_heading level0 col4" >Store_Sales</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_87655_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_87655_row0_col0" class="data row0 col0" >896.000000</td>
#       <td id="T_87655_row0_col1" class="data row0 col1" >896.000000</td>
#       <td id="T_87655_row0_col2" class="data row0 col2" >896.000000</td>
#       <td id="T_87655_row0_col3" class="data row0 col3" >896.000000</td>
#       <td id="T_87655_row0_col4" class="data row0 col4" >896.000000</td>
#     </tr>
#     <tr>
#       <th id="T_87655_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_87655_row1_col0" class="data row1 col0" >448.500000</td>
#       <td id="T_87655_row1_col1" class="data row1 col1" >1485.409598</td>
#       <td id="T_87655_row1_col2" class="data row1 col2" >1782.035714</td>
#       <td id="T_87655_row1_col3" class="data row1 col3" >786.350446</td>
#       <td id="T_87655_row1_col4" class="data row1 col4" >59351.305804</td>
#     </tr>
#     <tr>
#       <th id="T_87655_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_87655_row2_col0" class="data row2 col0" >258.797218</td>
#       <td id="T_87655_row2_col1" class="data row2 col1" >250.237011</td>
#       <td id="T_87655_row2_col2" class="data row2 col2" >299.872053</td>
#       <td id="T_87655_row2_col3" class="data row2 col3" >265.389281</td>
#       <td id="T_87655_row2_col4" class="data row2 col4" >17190.741895</td>
#     </tr>
#     <tr>
#       <th id="T_87655_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_87655_row3_col0" class="data row3 col0" >1.000000</td>
#       <td id="T_87655_row3_col1" class="data row3 col1" >775.000000</td>
#       <td id="T_87655_row3_col2" class="data row3 col2" >932.000000</td>
#       <td id="T_87655_row3_col3" class="data row3 col3" >10.000000</td>
#       <td id="T_87655_row3_col4" class="data row3 col4" >14920.000000</td>
#     </tr>
#     <tr>
#       <th id="T_87655_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_87655_row4_col0" class="data row4 col0" >224.750000</td>
#       <td id="T_87655_row4_col1" class="data row4 col1" >1316.750000</td>
#       <td id="T_87655_row4_col2" class="data row4 col2" >1575.500000</td>
#       <td id="T_87655_row4_col3" class="data row4 col3" >600.000000</td>
#       <td id="T_87655_row4_col4" class="data row4 col4" >46530.000000</td>
#     </tr>
#     <tr>
#       <th id="T_87655_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_87655_row5_col0" class="data row5 col0" >448.500000</td>
#       <td id="T_87655_row5_col1" class="data row5 col1" >1477.000000</td>
#       <td id="T_87655_row5_col2" class="data row5 col2" >1773.500000</td>
#       <td id="T_87655_row5_col3" class="data row5 col3" >780.000000</td>
#       <td id="T_87655_row5_col4" class="data row5 col4" >58605.000000</td>
#     </tr>
#     <tr>
#       <th id="T_87655_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_87655_row6_col0" class="data row6 col0" >672.250000</td>
#       <td id="T_87655_row6_col1" class="data row6 col1" >1653.500000</td>
#       <td id="T_87655_row6_col2" class="data row6 col2" >1982.750000</td>
#       <td id="T_87655_row6_col3" class="data row6 col3" >970.000000</td>
#       <td id="T_87655_row6_col4" class="data row6 col4" >71872.500000</td>
#     </tr>
#     <tr>
#       <th id="T_87655_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_87655_row7_col0" class="data row7 col0" >896.000000</td>
#       <td id="T_87655_row7_col1" class="data row7 col1" >2229.000000</td>
#       <td id="T_87655_row7_col2" class="data row7 col2" >2667.000000</td>
#       <td id="T_87655_row7_col3" class="data row7 col3" >1560.000000</td>
#       <td id="T_87655_row7_col4" class="data row7 col4" >116320.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df['Store_Area'].value_counts()
# Out:
# Store_Area
# 1539    5
# 1458    5
# 1439    5
# 1513    5
# 1440    5
#        ..
# 1263    1
# 1819    1
# 1357    1
# 1156    1
# 1072    1
# Name: count, Length: 583, dtype: int64
